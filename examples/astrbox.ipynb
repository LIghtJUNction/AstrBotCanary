# %%
from astrbox import main
main()
from astrbox import core

print("core:", core)
print("astrbox module loaded successfully.")


print(core.__doc__)
print(core.__name__)
print(core.__dict__)
# Out:
# Hello from astrbox!
# core: <module 'astrbox.core' from 'C:\\Users\\light\\Documents\\GitHub\\AstrBotCanary\\astrbox\\src\\astrbox\\core.pyd'>
# astrbox module loaded successfully.
#
# astrbox.core
# {'__name__': 'astrbox.core', '__doc__': '', '__package__': 'astrbox', '__loader__': <_frozen_importlib_external.ExtensionFileLoader object at 0x0000017FCD976690>, '__spec__': ModuleSpec(name='astrbox.core', loader=<_frozen_importlib_external.ExtensionFileLoader object at 0x0000017FCD976690>, origin='C:\\Users\\light\\Documents\\GitHub\\AstrBotCanary\\astrbox\\src\\astrbox\\core.pyd'), '__all__': ['hello_from_bin', 'cli'], 'hello_from_bin': <built-in function hello_from_bin>, 'cli': <module 'cli'>, '__file__': 'C:\\Users\\light\\Documents\\GitHub\\AstrBotCanary\\astrbox\\src\\astrbox\\core.pyd'}
