# %%
from astrbot_canary_paths import AstrbotPaths

print(AstrbotPaths.astrbot_root)

print(AstrbotPaths.getPaths("test_module").config)
# Out:
# c:\Users\light\Documents\GitHub\AstrBotCanary\astrbot_canary_paths\example\.astrbot
# c:\Users\light\Documents\GitHub\AstrBotCanary\astrbot_canary_paths\example\.astrbot\config\test-module
